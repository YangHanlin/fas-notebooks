# %% [markdown]
# # MNIST

# %% [markdown]
# ## Preparations

# %%
import numpy as np
import matplotlib.pyplot as plt
import pickle, gzip

# %%
with gzip.open('mnist.pkl.gz', 'rb') as file:
    train_set, valid_set, test_set = pickle.load(file, encoding='bytes')

# %% [markdown]
# ## Experiments

# %%
xplot = 7
yplot = 5

for i in range(xplot*yplot):
    plt.subplot(yplot, xplot, i+1)
    plt.imshow(train_set[0][i].reshape(28, 28), cmap='gray')
    # plt.xlabel(train_set[1][i])

plt.show()
